# %% [markdown]
# <a href="https://colab.research.google.com/github/champsleague/Data-Science-Projects/blob/main/DS_week7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = {'A': [45,37,42,35,39],
'B': [38,31,26,28,33],
'C': [10,15,17,21,12]
}
df = pd.DataFrame(data,columns=['A','B','C'])
# sample covariance matrix
covMatrix = pd.DataFrame.cov(df)
print (covMatrix)

import seaborn as sn
import matplotlib.pyplot as plt
sn.heatmap(covMatrix, annot=True, fmt='g')
plt.show()
# Out:
#       A      B      C
# A  15.8   9.60 -12.00
# B   9.6  21.70 -17.25
# C -12.0 -17.25  18.50

# %%
import numpy as np 
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt

#create data
spends = np.array([2400,2650,2350,4950,3100,2500,5106,3100,2900,1750])
income = np.array([41200,50100,52000,66000,44500,37700,73500,37500,56700,35600])

x = spends
y = income

#obtain m (slope) and b(intercept) of linear regression line
m, b = np.polyfit(x, y, 1)

#add linear regression line to scatterplot 
y=m*x+b
plt.plot(x, m*x+b)
print(y)

#create basic scatterplot
plt.plot(x, y, 'o')
plt.xlabel('spends')
plt.ylabel('income')
plt.show()
# Out:
# [42827.79206863 45271.30071224 42339.09033991 67751.58023347
#  49669.61627074 43805.19552607 69276.32962709 49669.61627074
#  47714.80935585 36474.66959524]
